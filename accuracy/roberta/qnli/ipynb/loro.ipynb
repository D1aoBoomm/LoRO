# %%
import os
os.environ["HF_ENDPOINT"] = "https://hf-mirror.com"

import sys
sys.path.append("../../../../LoRO")

from utils import *

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
from datasets import load_dataset
import tqdm

tokenizer = AutoTokenizer.from_pretrained("JeremiahZ/roberta-base-qnli")
model = AutoModelForSequenceClassification.from_pretrained("JeremiahZ/roberta-base-qnli")
# Out:
# /home/ubuntu/anaconda3/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
print(model)
# Out:
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
#obfuscate model
model = model_obfuscation(model)
print(model)
# Out:
# Obfuscating: roberta.encoder.layer.0.attention.self.query
# Obfuscating: roberta.encoder.layer.0.attention.self.key
# Obfuscating: roberta.encoder.layer.0.attention.self.value
# Obfuscating: roberta.encoder.layer.0.attention.output.dense
# Obfuscating: roberta.encoder.layer.0.intermediate.dense
# Obfuscating: roberta.encoder.layer.0.output.dense
# Obfuscating: roberta.encoder.layer.1.attention.self.query
# Obfuscating: roberta.encoder.layer.1.attention.self.key
# Obfuscating: roberta.encoder.layer.1.attention.self.value
# Obfuscating: roberta.encoder.layer.1.attention.output.dense
# Obfuscating: roberta.encoder.layer.1.intermediate.dense
# Obfuscating: roberta.encoder.layer.1.output.dense
# Obfuscating: roberta.encoder.layer.2.attention.self.query
# Obfuscating: roberta.encoder.layer.2.attention.self.key
# Obfuscating: roberta.encoder.layer.2.attention.self.value
# Obfuscating: roberta.encoder.layer.2.attention.output.dense
# Obfuscating: roberta.encoder.layer.2.intermediate.dense
# Obfuscating: roberta.encoder.layer.2.output.dense
# Obfuscating: roberta.encoder.layer.3.attention.self.query
# Obfuscating: roberta.encoder.layer.3.attention.self.key
# Obfuscating: roberta.encoder.layer.3.attention.self.value
# Obfuscating: roberta.encoder.layer.3.attention.output.dense
# Obfuscating: roberta.encoder.layer.3.intermediate.dense
# Obfuscating: roberta.encoder.layer.3.output.dense
# Obfuscating: roberta.encoder.layer.4.attention.self.query
# Obfuscating: roberta.encoder.layer.4.attention.self.key
# Obfuscating: roberta.encoder.layer.4.attention.self.value
# Obfuscating: roberta.encoder.layer.4.attention.output.dense
# Obfuscating: roberta.encoder.layer.4.intermediate.dense
# Obfuscating: roberta.encoder.layer.4.output.dense
# Obfuscating: roberta.encoder.layer.5.attention.self.query
# Obfuscating: roberta.encoder.layer.5.attention.self.key
# Obfuscating: roberta.encoder.layer.5.attention.self.value
# Obfuscating: roberta.encoder.layer.5.attention.output.dense
# Obfuscating: roberta.encoder.layer.5.intermediate.dense
# Obfuscating: roberta.encoder.layer.5.output.dense
# Obfuscating: roberta.encoder.layer.6.attention.self.query
# Obfuscating: roberta.encoder.layer.6.attention.self.key
# Obfuscating: roberta.encoder.layer.6.attention.self.value
# Obfuscating: roberta.encoder.layer.6.attention.output.dense
# Obfuscating: roberta.encoder.layer.6.intermediate.dense
# Obfuscating: roberta.encoder.layer.6.output.dense
# Obfuscating: roberta.encoder.layer.7.attention.self.query
# Obfuscating: roberta.encoder.layer.7.attention.self.key
# Obfuscating: roberta.encoder.layer.7.attention.self.value
# Obfuscating: roberta.encoder.layer.7.attention.output.dense
# Obfuscating: roberta.encoder.layer.7.intermediate.dense
# Obfuscating: roberta.encoder.layer.7.output.dense
# Obfuscating: roberta.encoder.layer.8.attention.self.query
# Obfuscating: roberta.encoder.layer.8.attention.self.key
# Obfuscating: roberta.encoder.layer.8.attention.self.value
# Obfuscating: roberta.encoder.layer.8.attention.output.dense
# Obfuscating: roberta.encoder.layer.8.intermediate.dense
# Obfuscating: roberta.encoder.layer.8.output.dense
# Obfuscating: roberta.encoder.layer.9.attention.self.query
# Obfuscating: roberta.encoder.layer.9.attention.self.key
# Obfuscating: roberta.encoder.layer.9.attention.self.value
# Obfuscating: roberta.encoder.layer.9.attention.output.dense
# Obfuscating: roberta.encoder.layer.9.intermediate.dense
# Obfuscating: roberta.encoder.layer.9.output.dense
# Obfuscating: roberta.encoder.layer.10.attention.self.query
# Obfuscating: roberta.encoder.layer.10.attention.self.key
# Obfuscating: roberta.encoder.layer.10.attention.self.value
# Obfuscating: roberta.encoder.layer.10.attention.output.dense
# Obfuscating: roberta.encoder.layer.10.intermediate.dense
# Obfuscating: roberta.encoder.layer.10.output.dense
# Obfuscating: roberta.encoder.layer.11.attention.self.query
# Obfuscating: roberta.encoder.layer.11.attention.self.key
# Obfuscating: roberta.encoder.layer.11.attention.self.value
# Obfuscating: roberta.encoder.layer.11.attention.output.dense
# Obfuscating: roberta.encoder.layer.11.intermediate.dense
# Obfuscating: roberta.encoder.layer.11.output.dense
# Obfuscating: classifier.dense
# Obfuscating: classifier.out_proj
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): LoroLinear(
#                 (obfus_linear): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (key): LoroLinear(
#                 (obfus_linear): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (value): LoroLinear(
#                 (obfus_linear): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): LoroLinear(
#                 (obfus_linear): Linear(in_features=768, out_features=768, bias=True)
#               )
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): LoroLinear(
#               (obfus_linear): Linear(in_features=768, out_features=3072, bias=True)
#             )
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): LoroLinear(
#               (obfus_linear): Linear(in_features=3072, out_features=768, bias=True)
#             )
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): LoroLinear(
#       (obfus_linear): Linear(in_features=768, out_features=768, bias=True)
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): LoroLinear(
#       (obfus_linear): Linear(in_features=768, out_features=2, bias=True)
#     )
#   )
# )

# %%
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer, device='cuda')

# %%
# two examples from training set

question = "When did the third Digimon series begin?"
sentence = "Unlike the two seasons before it and most of the seasons that followed, Digimon Tamers takes a darker and more realistic approach to its story featuring Digimon who do not reincarnate after their deaths and more complex character development in the original Japanese."

print(classifier(question+" "+sentence))

question = "What two things does Popper argue Tarski's theory involves in an evaluation of truth?"
sentence = "He bases this interpretation on the fact that examples such as the one described above refer to two things: assertions and the facts to which they refer."
print(classifier(question+" "+sentence))
# Out:
# [{'label': 'not_entailment', 'score': 0.9956406354904175}]
# [{'label': 'entailment', 'score': 0.9965680837631226}]

# %%
dataset = load_dataset("glue", "qnli")['validation']
print(dataset)
# Out:
# Dataset({
#     features: ['question', 'sentence', 'label', 'idx'],
#     num_rows: 5463
# })

# %%
correct = 0
total = 0

for i in tqdm.tqdm(range(5463)):
    result = classifier(dataset[i]['question'] + " " + dataset[i]['sentence'])
    result = 0 if result[0]['label'] == 'entailment' else 1
    if result == dataset[i]['label']:
        correct += 1
    total += 1

print("correct:{}, total:{}, accuracy:{}".format(correct, total, correct/total))
# Out:
#   0%|          | 7/5463 [00:00<01:25, 63.64it/s]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 100%|██████████| 5463/5463 [00:57<00:00, 94.24it/s]
# correct:5019, total:5463, accuracy:0.9187259747391543
